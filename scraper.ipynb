# %%
import snscrape.modules.twitter as sntwitter
from datetime import datetime
import time
import random
import pandas as pd
import nltk
from dotenv import load_dotenv
import os
import re

# %%
twitter_username = os.getenv("TWT_USERNAME")
twitter_password = os.getenv("TWT_PASSWORD")

# %%
twitter_user = sntwitter.TwitterUserScraper("mehmetdemirkolb")
tweets_mehmetdemirkolb = []
for i, tweet in enumerate(twitter_user.get_items()):
    if i == 500:
        break

    if i % 5 == 0:
        print("Getting item:", i)

    tweets_mehmetdemirkolb.append(tweet)
# Out:
# Getting item: 0
# Getting item: 5
# Getting item: 10
# Getting item: 15
# Getting item: 20
# Getting item: 25
# Getting item: 30
# Getting item: 35
# Getting item: 40
# Getting item: 45
# Getting item: 50
# Getting item: 55
# Getting item: 60
# Getting item: 65
# Getting item: 70
# Getting item: 75
# Getting item: 80
# Getting item: 85
# Getting item: 90
# Getting item: 95
# Getting item: 100
# Getting item: 105
# Getting item: 110
# Getting item: 115
# Getting item: 120
# Getting item: 125
# Getting item: 130
# Getting item: 135
# Getting item: 140
# Getting item: 145
# Getting item: 150
# Getting item: 155
# Getting item: 160
# Getting item: 165
# Getting item: 170
# Getting item: 175
# Getting item: 180
# Getting item: 185
# Getting item: 190
# Getting item: 195
# Getting item: 200
# Getting item: 205
# Getting item: 210
# Getting item: 215
# Getting item: 220
# Getting item: 225
# Getting item: 230
# Getting item: 235
# Getting item: 240
# Getting item: 245
# Getting item: 250
# ...

# %%
twitter_user = sntwitter.TwitterUserScraper("demirtasmst")
tweets_demirtasmst = []
for i, tweet in enumerate(twitter_user.get_items()):
    if i == 500:
        break

    if i % 5 == 0:
        print("Getting item:", i)

    tweets_demirtasmst.append(tweet)
# Out:
# Getting item: 0
# Getting item: 5
# Getting item: 10
# Getting item: 15
# Getting item: 20
# Getting item: 25
# Getting item: 30
# Getting item: 35
# Getting item: 40
# Getting item: 45
# Getting item: 50
# Getting item: 55
# Getting item: 60
# Getting item: 65
# Getting item: 70
# Getting item: 75
# Getting item: 80
# Getting item: 85
# Getting item: 90
# Getting item: 95
# Getting item: 100
# Getting item: 105
# Getting item: 110
# Getting item: 115
# Getting item: 120
# Getting item: 125
# Getting item: 130
# Getting item: 135
# Getting item: 140
# Getting item: 145
# Getting item: 150
# Getting item: 155
# Getting item: 160
# Getting item: 165
# Getting item: 170
# Getting item: 175
# Getting item: 180
# Getting item: 185
# Getting item: 190
# Getting item: 195
# Getting item: 200
# Getting item: 205
# Getting item: 210
# Getting item: 215
# Getting item: 220
# Getting item: 225
# Getting item: 230
# Getting item: 235
# Getting item: 240
# Getting item: 245
# Getting item: 250
# ...

# %%
twitter_user = sntwitter.TwitterUserScraper("ersinduzen")
tweets_ersinduzen = []
for i, tweet in enumerate(twitter_user.get_items()):
    if i == 500:
        break

    if i % 5 == 0:
        print("Getting item:", i)

    tweets_ersinduzen.append(tweet)
# Out:
# Getting item: 0
# Getting item: 5
# Getting item: 10
# Getting item: 15
# Getting item: 20
# Getting item: 25
# Getting item: 30
# Getting item: 35
# Getting item: 40
# Getting item: 45
# Getting item: 50
# Getting item: 55
# Getting item: 60
# Getting item: 65
# Getting item: 70
# Getting item: 75
# Getting item: 80
# Getting item: 85
# Getting item: 90
# Getting item: 95
# Getting item: 100
# Getting item: 105
# Getting item: 110
# Getting item: 115
# Getting item: 120
# Getting item: 125
# Getting item: 130
# Getting item: 135
# Getting item: 140
# Getting item: 145
# Getting item: 150
# Getting item: 155
# Getting item: 160
# Getting item: 165
# Getting item: 170
# Getting item: 175
# Getting item: 180
# Getting item: 185
# Getting item: 190
# Getting item: 195
# Getting item: 200
# Getting item: 205
# Getting item: 210
# Getting item: 215
# Getting item: 220
# Getting item: 225
# Getting item: 230
# Getting item: 235
# Getting item: 240
# Getting item: 245
# Getting item: 250
# ...

# %%
twitter_user = sntwitter.TwitterUserScraper("ukarakullukcu")
tweets_ukarakullukcu = []
for i, tweet in enumerate(twitter_user.get_items()):
    if i == 500:
        break

    if i % 5 == 0:
        print("Getting item:", i)

    tweets_ukarakullukcu.append(tweet)
# Out:
# Getting item: 0
# Getting item: 5
# Getting item: 10
# Getting item: 15
# Getting item: 20
# Getting item: 25
# Getting item: 30
# Getting item: 35
# Getting item: 40
# Getting item: 45
# Getting item: 50
# Getting item: 55
# Getting item: 60
# Getting item: 65
# Getting item: 70
# Getting item: 75
# Getting item: 80
# Getting item: 85
# Getting item: 90
# Getting item: 95
# Getting item: 100
# Getting item: 105
# Getting item: 110
# Getting item: 115
# Getting item: 120
# Getting item: 125
# Getting item: 130
# Getting item: 135
# Getting item: 140
# Getting item: 145
# Getting item: 150
# Getting item: 155
# Getting item: 160
# Getting item: 165
# Getting item: 170
# Getting item: 175
# Getting item: 180
# Getting item: 185
# Getting item: 190
# Getting item: 195
# Getting item: 200
# Getting item: 205
# Getting item: 210
# Getting item: 215
# Getting item: 220
# Getting item: 225
# Getting item: 230
# Getting item: 235
# Getting item: 240
# Getting item: 245
# Getting item: 250
# ...

# %%
twitter_user = sntwitter.TwitterUserScraper("trtspor")
tweets_trtspor = []
for i, tweet in enumerate(twitter_user.get_items()):
    if i == 1000:
        break

    if i % 5 == 0:
        print("Getting item:", i)

    tweets_trtspor.append(tweet)
# Out:
# Getting item: 0
# Getting item: 5
# Getting item: 10
# Getting item: 15
# Getting item: 20
# Getting item: 25
# Getting item: 30
# Getting item: 35
# Getting item: 40
# Getting item: 45
# Getting item: 50
# Getting item: 55
# Getting item: 60
# Getting item: 65
# Getting item: 70
# Getting item: 75
# Getting item: 80
# Getting item: 85
# Getting item: 90
# Getting item: 95
# Getting item: 100
# Getting item: 105
# Getting item: 110
# Getting item: 115
# Getting item: 120
# Getting item: 125
# Getting item: 130
# Getting item: 135
# Getting item: 140
# Getting item: 145
# Getting item: 150
# Getting item: 155
# Getting item: 160
# Getting item: 165
# Getting item: 170
# Getting item: 175
# Getting item: 180
# Getting item: 185
# Getting item: 190
# Getting item: 195
# Getting item: 200
# Getting item: 205
# Getting item: 210
# Getting item: 215
# Getting item: 220
# Getting item: 225
# Getting item: 230
# Getting item: 235
# Getting item: 240
# Getting item: 245
# Getting item: 250
# ...

# %%
type(tweets_mehmetdemirkolb[0])
type(tweets_demirtasmst[0])
type(tweets_ersinduzen[0])
type(tweets_ukarakullukcu[0])
type(tweets_trtspor[0])
# Out:
# snscrape.modules.twitter.Tweet

# %%
tweets_mehmetdemirkolb[0]
# Out:
# Tweet(url='https://twitter.com/mehmetdemirkolb/status/1610352073513500672', date=datetime.datetime(2023, 1, 3, 19, 7, 7, tzinfo=datetime.timezone.utc), content='Ofsaytımsılar... Faulümsüler...', renderedContent='Ofsaytımsılar... Faulümsüler...', id=1610352073513500672, user=User(username='mehmetdemirkolb', id=1477866582, displayname='mehmet demirkol', description='instagram.com/mehmetdemirkolb', rawDescription='https://t.co/pZAFADFeEx', descriptionUrls=[{'text': 'instagram.com/mehmetdemirkolb', 'url': 'http://instagram.com/mehmetdemirkolb', 'tcourl': 'https://t.co/pZAFADFeEx', 'indices': (0, 23)}], verified=True, created=datetime.datetime(2013, 6, 2, 18, 16, 44, tzinfo=datetime.timezone.utc), followersCount=1318429, friendsCount=886, statusesCount=3308, favouritesCount=3004, listedCount=1244, mediaCount=202, location='istanbul', protected=False, linkUrl='https://youtube.com/playlist?list=PLoVoFW70X9kiZ-HKMWeawWZ3NkgnNGa8b', linkTcourl='https://t.co/c35jEnrYyJ', profileImageUrl='https
# ...

# %%
tweets_demirtasmst[0]
# Out:
# Tweet(url='https://twitter.com/demirtasmst/status/1610991239893241857', date=datetime.datetime(2023, 1, 5, 13, 26, 57, tzinfo=datetime.timezone.utc), content='Kadro doğru "tamamlandığında" ve rol paylaşımı dengeli olduğunda, Barış Alper Yılmaz, Berkan Kutlu gibi oyuncuların performansına olumlu yansıması üzerine:\nhttps://t.co/HjZ90re2vV', renderedContent='Kadro doğru "tamamlandığında" ve rol paylaşımı dengeli olduğunda, Barış Alper Yılmaz, Berkan Kutlu gibi oyuncuların performansına olumlu yansıması üzerine:\nyoutube.com/watch?v=uaUXVY…', id=1610991239893241857, user=User(username='demirtasmst', id=131339783, displayname='Mustafa Demirtaş', description='Yorumcu: @VOLEapp\nİletişim: demirtasmst@gmail.com\nYouTube kanalım: youtube.com/@serbest8?sub_…', rawDescription='Yorumcu: @VOLEapp\nİletişim: demirtasmst@gmail.com\nYouTube kanalım: https://t.co/1DKhFsrWHo…', descriptionUrls=[{'text': 'youtube.com/@serbest8?sub_', 'url': 'http://youtube.com/@serbest8?sub_', 'tcourl': 'https://t.co/
# ...

# %%
tweets_ersinduzen[0]
# Out:
# Tweet(url='https://twitter.com/ersinduzen/status/1610618078223814657', date=datetime.datetime(2023, 1, 4, 12, 44, 8, tzinfo=datetime.timezone.utc), content='@ctisik @kafadergisi Nice 100’lere🧿', renderedContent='@ctisik @kafadergisi Nice 100’lere🧿', id=1610618078223814657, user=User(username='ersinduzen', id=64693618, displayname='Ersin Düzen', description='@voleapp📍🇹🇷 ersinduzen620@gmail.com football commentator-broadcaster-journalist-anchor-columnist instagram.com/ersinduzen', rawDescription='@voleapp📍🇹🇷 ersinduzen620@gmail.com football commentator-broadcaster-journalist-anchor-columnist https://t.co/LCqy03BLZR', descriptionUrls=[{'text': 'instagram.com/ersinduzen', 'url': 'http://instagram.com/ersinduzen', 'tcourl': 'https://t.co/LCqy03BLZR', 'indices': (97, 120)}], verified=True, created=datetime.datetime(2009, 8, 11, 11, 55, 42, tzinfo=datetime.timezone.utc), followersCount=623629, friendsCount=1833, statusesCount=23000, favouritesCount=8308, listedCount=963, mediaCount=1914, lo
# ...

# %%
tweets_ukarakullukcu[0]
# Out:
# Tweet(url='https://twitter.com/trtspor/status/1611022210021445636', date=datetime.datetime(2023, 1, 5, 15, 30, tzinfo=datetime.timezone.utc), content='✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitexen Giresunspor🟢\n\n⌚️20.00\n🏟️Medical Park Stadyumu\n📻TRT RADYO 1\n\n#TSvGRS https://t.co/9admFao9EZ', renderedContent='✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitexen Giresunspor🟢\n\n⌚️20.00\n🏟️Medical Park Stadyumu\n📻TRT RADYO 1\n\n#TSvGRS https://t.co/9admFao9EZ', id=1611022210021445636, user=User(username='trtspor', id=368948189, displayname='TRT Spor', description='#TRTSporDijital Sporun her rengi için @trtsporyildiz', rawDescription='#TRTSporDijital Sporun her rengi için @trtsporyildiz', descriptionUrls=None, verified=True, created=datetime.datetime(2011, 9, 6, 14, 12, 20, tzinfo=datetime.timezone.utc), followersCount=2279492, friendsCount=11, statusesCount=356283, favouritesCount=9, listedCount=1746, mediaCount=159871, location='Türkiye', protected=False, linkUrl='https://www.trtspo
# ...

# %%
tweets_mehmetdemirkolb[0].content
# Out:
# 'Ofsaytımsılar... Faulümsüler...'

# %%
tweets_demirtasmst[0].content
# Out:
# 'Kadro doğru "tamamlandığında" ve rol paylaşımı dengeli olduğunda, Barış Alper Yılmaz, Berkan Kutlu gibi oyuncuların performansına olumlu yansıması üzerine:\nhttps://t.co/HjZ90re2vV'

# %%
tweets_ersinduzen[0].content
# Out:
# '@ctisik @kafadergisi Nice 100’lere🧿'

# %%
tweets_ukarakullukcu[0].content
# Out:
# '✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitexen Giresunspor🟢\n\n⌚️20.00\n🏟️Medical Park Stadyumu\n📻TRT RADYO 1\n\n#TSvGRS https://t.co/9admFao9EZ'

# %%
tweets_trtspor[0].content
# Out:
# '✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitexen Giresunspor🟢\n\n⌚️20.00\n🏟️Medical Park Stadyumu\n📻TRT RADYO 1\n\n#TSvGRS https://t.co/9admFao9EZ'

# %%
df_mehmetdemirkolb = pd.DataFrame(tweets_mehmetdemirkolb)
df_mehmetdemirkolb.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/mehmetdemirkolb/status/161...
# 1  https://twitter.com/mehmetdemirkolb/status/161...
# 2  https://twitter.com/mehmetdemirkolb/status/160...
# 3  https://twitter.com/mehmetdemirkolb/status/160...
# 4  https://twitter.com/mehmetdemirkolb/status/160...
#
#                        date  \
# 0 2023-01-03 19:07:07+00:00
# 1 2023-01-03 14:09:32+00:00
# 2 2022-12-30 19:21:02+00:00
# 3 2022-12-27 08:00:32+00:00
# 4 2022-12-23 20:11:27+00:00
#
#                                              content  \
# 0                    Ofsaytımsılar... Faulümsüler...
# 1                                      Ofsaytımsı...
# 2  Yılbaşı özel!\nYılın enleri... https://t.co/go...
# 3                   Başladık https://t.co/B9YKdyYS6K
# 4  Yılbaşına az kaldı. Buyrunuz. https://t.co/j9Q...
#
#                                      renderedContent                   id  \
# ...

# %%
df_mehmetdemirkolb.to_csv("mehmetdemirkolb.csv", index=False)

# %%
df_demirtasmst = pd.DataFrame(tweets_demirtasmst)
df_demirtasmst.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/demirtasmst/status/1610991...
# 1  https://twitter.com/demirtasmst/status/1609576...
# 2  https://twitter.com/demirtasmst/status/1609575...
# 3  https://twitter.com/demirtasmst/status/1609574...
# 4  https://twitter.com/demirtasmst/status/1609552...
#
#                        date  \
# 0 2023-01-05 13:26:57+00:00
# 1 2023-01-01 15:46:03+00:00
# 2 2023-01-01 15:39:31+00:00
# 3 2023-01-01 15:35:42+00:00
# 4 2023-01-01 14:08:02+00:00
#
#                                              content  \
# 0  Kadro doğru "tamamlandığında" ve rol paylaşımı...
# 1  @orkunco Onun da eli titremesin Bryan Gil'i bi...
# 2  @KarlHeinzZero Kanat bekler de düz 8 numaralar...
# 3  Tottenham uzun zamandır fena halde. İyi yapabi...
# 4  @YvzKndmr_isik Normal ya burada da sesli düşün...
#
#                                      renderedContent                   id  \
# ...

# %%
df_demirtasmst.to_csv("demirtasmst.csv", index=False)

# %%
df_ersinduzen = pd.DataFrame(tweets_ersinduzen)
df_ersinduzen.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ersinduzen/status/16106180...
# 1  https://twitter.com/ersinduzen/status/16105946...
# 2  https://twitter.com/ersinduzen/status/16103525...
# 3  https://twitter.com/ersinduzen/status/16102672...
# 4  https://twitter.com/ersinduzen/status/16100418...
#
#                        date  \
# 0 2023-01-04 12:44:08+00:00
# 1 2023-01-04 11:11:01+00:00
# 2 2023-01-03 19:09:06+00:00
# 3 2023-01-03 13:30:07+00:00
# 4 2023-01-02 22:34:17+00:00
#
#                                              content  \
# 0                @ctisik @kafadergisi Nice 100’lere🧿
# 1  VOLE canlı yayınında 27 bin izleyicimiz biziml...
# 2  Başladık🔥\nKonuşacak çok şey var! \n\n📲 https:...
# 3  Futbolun hangi hakemlere emanet edildiği, yete...
# 4  @ismailsaymaz Tebrikler. Ömrü sağlıklı ve uzun...
#
#                                      renderedContent                   id  \
# ...

# %%
df_ersinduzen.to_csv("ersinduzen.csv", index=False)

# %%
df_ukarakullukcu = pd.DataFrame(tweets_ukarakullukcu)
df_ukarakullukcu.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/trtspor/status/16110222100...
# 1  https://twitter.com/trtspor/status/16110185586...
# 2  https://twitter.com/trtspor/status/16110146669...
# 3  https://twitter.com/trtspor/status/16110129646...
# 4  https://twitter.com/trtspor/status/16110108834...
#
#                        date  \
# 0 2023-01-05 15:30:00+00:00
# 1 2023-01-05 15:15:30+00:00
# 2 2023-01-05 15:00:02+00:00
# 3 2023-01-05 14:53:16+00:00
# 4 2023-01-05 14:45:00+00:00
#
#                                              content  \
# 0  ✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitex...
# 1  🗣️"Burada olduğum için çok mutluyum. Yakında g...
# 2  🏃‍♂️Cristiano Ronaldo, yeni takımı Al Nassr il...
# 3  Berkay Özcan'ın ilk yarının skorunu belirleyen...
# 4  ✍  PSG, 18 yaşındaki orta saha oyuncusu Ayman ...
#
#                                      renderedContent                   id  \
# ...

# %%
df_ukarakullukcu.to_csv("ukarakullukcu.csv", index=False)

# %%
df_trtspor = pd.DataFrame(tweets_trtspor)
df_trtspor.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/trtspor/status/16110222100...
# 1  https://twitter.com/trtspor/status/16110185586...
# 2  https://twitter.com/trtspor/status/16110146669...
# 3  https://twitter.com/trtspor/status/16110129646...
# 4  https://twitter.com/trtspor/status/16110108834...
#
#                        date  \
# 0 2023-01-05 15:30:00+00:00
# 1 2023-01-05 15:15:30+00:00
# 2 2023-01-05 15:00:02+00:00
# 3 2023-01-05 14:53:16+00:00
# 4 2023-01-05 14:45:00+00:00
#
#                                              content  \
# 0  ✍️Cevaplarınızı yazın...\n\n🔴Trabzonspor🆚Bitex...
# 1  🗣️"Burada olduğum için çok mutluyum. Yakında g...
# 2  🏃‍♂️Cristiano Ronaldo, yeni takımı Al Nassr il...
# 3  Berkay Özcan'ın ilk yarının skorunu belirleyen...
# 4  ✍  PSG, 18 yaşındaki orta saha oyuncusu Ayman ...
#
#                                      renderedContent                   id  \
# ...

# %%
df_trtspor.to_csv("trtspor.csv", index=False)

# %%
import os

# %%
import pandas as pd

# %%
folder_path = "C:\\Users\\enes2\\Desktop\\nlp_twitter\\dosya"

# %%
all_filenames = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %%
df_combined = pd.concat([pd.read_csv(os.path.join(folder_path, f)) for f in all_filenames])

# %%
df_combined.to_csv('combined.csv', index=False, encoding='utf-8-sig')

# %%
df_loaded = pd.read_csv("combined.csv")
df_loaded.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/demirtasmst/status/1610991...
# 1  https://twitter.com/demirtasmst/status/1609576...
# 2  https://twitter.com/demirtasmst/status/1609575...
# 3  https://twitter.com/demirtasmst/status/1609574...
# 4  https://twitter.com/demirtasmst/status/1609552...
#
#                         date  \
# 0  2023-01-05 13:26:57+00:00
# 1  2023-01-01 15:46:03+00:00
# 2  2023-01-01 15:39:31+00:00
# 3  2023-01-01 15:35:42+00:00
# 4  2023-01-01 14:08:02+00:00
#
#                                              content  \
# 0  Kadro doğru "tamamlandığında" ve rol paylaşımı...
# 1  @orkunco Onun da eli titremesin Bryan Gil'i bi...
# 2  @KarlHeinzZero Kanat bekler de düz 8 numaralar...
# 3  Tottenham uzun zamandır fena halde. İyi yapabi...
# 4  @YvzKndmr_isik Normal ya burada da sesli düşün...
#
#                                      renderedContent                   id  \
# ...

# %%
combined_df = df_combined[['content']]
combined_df.to_csv('combined.csv',index=False)

# %%
import string

# %%
stop_words = sorted(["ile","ve","imza","bir","bu","daha","için","bey","sağ","olun","the","and","to","of","we"
,"in","or","de","tüm","da","her","en","çok","sosyal","lig","ali","ece","Serdar","Ali","KazanmakİçinOyna","📲","petrolofisi"])

# %%
def clean_text(text):
    text = re.sub("https?://\S+", "", text)
    text = text.replace("\\n", " ")
    text = re.sub("[0-9]+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub("’|“|”|‘|–|—", "", text)
    text = re.sub(" 🇹🇷", "", text)
    text = [t for t in text.split() if t not in stop_words]
    return " ".join(text)

# %%
combined_df["clean"] = combined_df.apply(lambda row: clean_text(row["content"]), axis=1)
# Out:
# C:\Users\enes2\AppData\Local\Temp\ipykernel_5488\3488899882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df["clean"] = combined_df.apply(lambda row: clean_text(row["content"]), axis=1)

# %%
combined_df["clean"][:10]
# Out:
# C:\Users\enes2\AppData\Local\Temp\ipykernel_5488\3741094124.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   combined_df["clean"][:10]
# 0    Kadro doğru tamamlandığında rol paylaşımı deng...
# 1    orkunco Onun eli titremesin Bryan Gili bi kana...
# 2    KarlHeinzZero Kanat bekler düz numaralar Sadec...
# 3    Tottenham uzun zamandır fena halde İyi yapabil...
# 4    YvzKndmrisik Normal ya burada sesli düşünüyoru...
# 5    muhammetunsl Aslında Cagliarideyken adı çıkıyo...
# 6    Arsenal şahane maçlarına yenisini ekledi akşam...
# 7    otobusbekliyom milyonu indirmek isteyebilir ta...
# 8    Gkhnxylmz Zidaneın finali mesela iyi örnek Dün...
# 9    Cristiano Ronaldonun Al Nassr transferi yaptığ...
# Name: clean, dtype: object

# %%
cleaned_df = combined_df[['clean']]
cleaned_df.to_csv('combined_clean.csv',index=False)

# %%
cleaned_df.head()
# Out:
#                                                clean
# 0  Kadro doğru tamamlandığında rol paylaşımı deng...
# 1  orkunco Onun eli titremesin Bryan Gili bi kana...
# 2  KarlHeinzZero Kanat bekler düz numaralar Sadec...
# 3  Tottenham uzun zamandır fena halde İyi yapabil...
# 4  YvzKndmrisik Normal ya burada sesli düşünüyoru...

# %%
df = pd.read_csv('combined_clean.csv')

df.dropna(subset=['clean'], inplace=True)

df['tokens'] = df['clean'].apply(nltk.word_tokenize)

df['bigrams'] = df['tokens'].apply(lambda x: list(nltk.bigrams(x)))

bigram_freq = pd.Series([bigram for bigrams in df['bigrams'] for bigram in bigrams]).value_counts()

print(bigram_freq.head(20))
# Out:
# (Dünya, Kupası)                 19
# (sosyallig, işbirliği)          14
# (Şampiyonlar, Ligi)             14
# (orta, saha)                    12
# (Ersin, Düzen)                  12
# (Çok, iyi)                      11
# (Wordle, Türkçe)                10
# (Arda, Güler)                    9
# (Jorge, Jesus)                   9
# (olmak, üzere)                   9
# (şu, an)                         8
# (hemen, şimdi)                   8
# (Real, Madrid)                   8
# (cennet, olsun)                  8
# (Joao, Pedro)                    8
# (o, kadar)                       8
# (amp, Ece)                       8
# (orta, sahada)                   8
# (ukarakullukcu, demirtasmst)     7
# (Bu, arada)                      7
# dtype: int64
